# %% [markdown]
# # Sistema de gestión de Videojuegos
#
# ## **Objetivo**
# Crear un sistema en python para admiistrar videojuegos utilizando:
#
# -Diccionarios
#
# -Funciones
#
# -Ciclos
#
# -Condicionales
#
# ---
#
# ## Inventario inicial
#
# En esta sección se crea un diccionario para almacenar la información de los videojuegos disponibles en la tienda.
#
# Cada videojuego contiene:
# - Código
# - Nombre
# - Plataforma
# - Precio
# - Cantidad disponible

# %% [markdown]
# ## Explicación
#
# Para almacenar la información de los videojuegos se utiliza un diccionario anidado.
#
# Cada videojuego tiene un código único y almacena información como nombre, plataforma, precio y cantidad disponible.

# %%
videojuegos = {
    "VG001": {
        "nombre": "FIFA 26",
        "plataforma": "PlayStation 5",
        "precio": 250000,
        "cantidad": 10
    },

    "VG002": {
        "nombre": "Zelda: Breath of the Wild",
        "plataforma": "Nintendo Switch",
        "precio": 220000,
        "cantidad": 5
    },

    "VG003": {
        "nombre": "Forza Horizon 5",
        "plataforma": "Xbox Series X",
        "precio": 210000,
        "cantidad": 8
    }
}

# %%
videojuegos["VG001"]
# Out:
# {'nombre': 'FIFA 26',
#  'plataforma': 'PlayStation 5',
#  'precio': 250000,
#  'cantidad': 10}

# %% [markdown]
# ## Conclusión
#
# Se utilizó un diccionario anidado para almacenar la información de los videojuegos.
#
# También se realizó una prueba de acceso a los datos utilizando el código de un videojuego para verificar que la información se encuentra almacenada correctamente.
